# %%
# %%HTML
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>David 1</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#
#     <!-- this is the start of content -->
#     <h3>
#       Salut à tous, les 2ndC ! Je m'appelle David1.
#     </h3>
#         <DIV class="avatar">
#   <img src="https://cdn.glitch.me/d3b37b8e-5778-4db7-be52-30a48464c306%2FYo.jpg?v=1639304150975" style="width:115px"/>
#     </DIV>
#     <br>
#     <p>
# L'une de mes passions est l'informatique. Je m'intéresse à la 'Computer vision'. Cela m'amènne
# à écrire des scripts en python de reconnaissance faciale, ou de 'Cape d'invisibilité'. Voici des exemples de résultats :
#     </p>
#     <DIV>
#             <img src="https://cdn.glitch.me/d3b37b8e-5778-4db7-be52-30a48464c306%2FEx3.jpg?v=1639304913862" style="width:400px"/>
#         <img src="https://cdn.glitch.me/d3b37b8e-5778-4db7-be52-30a48464c306%2FCape.jpg?v=1639304765107" />
# <iframe width="450" height="315" src="https://www.youtube.com/embed/RbZNrDFwvwI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#     </DIV>
#     <p>
#       Voici un lien vers la page de mon camarade David2 :
#                 <a href="https://2021-avatar2.glitch.me"
#         >ici</a>.
#     </p>
#
#   </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>David 1</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#
#     <!-- this is the start of content -->
#     <h3>
#       Salut à tous, les 2ndC ! Je m'appelle David1.
#     </h3>
#         <DIV class="avatar">
#   <img src="https://cdn.glitch.me/d3b37b8e-5778-4db7-be52-30a48464c306%2FYo.jpg?v=1639304150975" style="width:115px"/>
#     </DIV>
#     <br>
#     <p>
# L'une de mes passions est l'informatique. Je m'intéresse à la 'Computer vision'. Cela m'amènne
# ...

# %%
import ipywidgets as widgets

# %%
def ChangeImage(change):
        valeur=change['new']
        if valeur == 1:
            Titre_image = "Cape.jpg"
            file = open(Titre_image, "rb")
            image = file.read()
            img.value = image
        elif valeur == 2:
            Titre_image = "Ex3.jpg" 
            file = open(Titre_image, "rb")
            image = file.read()
            img.value = image

# %%
Titre_image = "Cape.jpg"

# %%
slide = widgets.IntSlider(
    value=1,
    min=1,
    max=2,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
display(slide)
slide.observe(ChangeImage, names='value')
# Out:
# IntSlider(value=1, continuous_update=False, description='Test:', max=2, min=1)

# %%
file = open(Titre_image, "rb")
image = file.read()
img = widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400,
)
display(img)
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\…
